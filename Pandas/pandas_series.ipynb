# %% [markdown]
# ## What is Pandas?

# %% [markdown]
# Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language.
#
# A pandas series is like a column in a table. It is a 1-D array holding data of any type. One row/column of the pandas dataframe is pandas series.

# %% [markdown]
# ## Importing Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Series Using Lists

# %%
# string (object)
country = ['Nepal', 'India', 'Bangladesh', 'China','Srilanka']

pd.Series(country)
# Out:
# 0         Nepal
# 1         India
# 2    Bangladesh
# 3         China
# 4      Srilanka
# dtype: object

# %%
# integers
runs = [13,24,56,78,100]

runs_series = pd.Series(runs)
runs_series
# Out:
# 0     13
# 1     24
# 2     56
# 3     78
# 4    100
# dtype: int64

# %%
# custom index

marks = [67,57,89,100]
subjects = ['maths','english','science','nepali']

pd.Series(marks, index=subjects)
# Out:
# maths       67
# english     57
# science     89
# nepali     100
# dtype: int64

# %%
# setting a name

marks_series = pd.Series(marks, index=subjects, name="marks of sandip" )
marks_series
# Out:
# maths       67
# english     57
# science     89
# nepali     100
# Name: marks of sandip, dtype: int64

# %% [markdown]
# ## Series From Dictionary

# %%
marks = {   
    'maths': 67,
    'english':57,
    'science':89,
    'nepali':100
}

marks_series = pd.Series(marks,name="marks of sandip")
marks_series
# Out:
# maths       67
# english     57
# science     89
# nepali     100
# Name: marks of sandip, dtype: int64

# %% [markdown]
# ## Series Attributes

# %%
marks_series
# Out:
# maths       67
# english     57
# science     89
# nepali     100
# Name: marks of sandip, dtype: int64

# %%
# size
marks_series.size
# Out:
# 4

# %%
# dtype
marks_series.dtype
# Out:
# dtype('int64')

# %%
# name
marks_series.name
# Out:
# 'marks of sandip'

# %%
# is_unique
marks_series.is_unique
# Out:
# True

# %%
pd.Series([1,1,2,3,4,4,5]).is_unique
# Out:
# False

# %%
# index
marks_series.index
# Out:
# Index(['maths', 'english', 'science', 'nepali'], dtype='object')

# %%
type(marks_series.index)
# Out:
# pandas.core.indexes.base.Index

# %%
# values
marks_series.values
# Out:
# array([ 67,  57,  89, 100])

# %%
type(marks_series.values)
# Out:
# numpy.ndarray

# %% [markdown]
# ## Series Using read_csv

# %%
import os 
csv_file_path1 = fr"C:\Users\sanje\Desktop\Python_Frameworks_For_Machine_Learning\datafiles\subs.csv"
dataframe = pd.read_csv(csv_file_path1)
dataframe
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
type(pd.read_csv(csv_file_path1))
# Out:
# pandas.core.frame.DataFrame

# %%
# with one column
subs = dataframe.squeeze('columns')  # squeeze() method is used to convert into series
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
type(subs)
# Out:
# pandas.core.series.Series

# %%
# with two column
csv_file_path2 = fr"C:\Users\sanje\Desktop\Python_Frameworks_For_Machine_Learning\datafiles\kohli_ipl.csv"
vk_runs = pd.read_csv(csv_file_path2,index_col="match_no").squeeze('columns')
vk_runs
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
csv_file_path3 = fr"C:\Users\sanje\Desktop\Python_Frameworks_For_Machine_Learning\datafiles\bollywood.csv"
movies = pd.read_csv(csv_file_path3, index_col="movie").squeeze('columns')
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# ## Series Methods

# %%
# head and tail
subs.head()  # by default top 5
# Out:
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# Name: Subscribers gained, dtype: int64

# %%
vk_runs.head(3)
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# Name: runs, dtype: int64

# %%
vk_runs.tail()
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
vk_runs.tail(10)
# Out:
# match_no
# 206     0
# 207     0
# 208     9
# 209    58
# 210    30
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
# sample -> returns one row randomly
movies.sample()
# Out:
# movie
# Love Aaj Kal    Saif Ali Khan
# Name: lead, dtype: object

# %%
movies.sample(5)
# Out:
# movie
# One Day: Justice Delivered           Anupam Kher
# Hastey Hastey                    Jimmy Sheirgill
# De Taali                        Aftab Shivdasani
# Bareilly Ki Barfi             Ayushmann Khurrana
# Sunday (2008 film)                    Ajay Devgn
# Name: lead, dtype: object

# %%
# value_counts -> counts the frequency of value 
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
movies.value_counts()
# Out:
# lead
# Akshay Kumar            48
# Amitabh Bachchan        45
# Ajay Devgn              38
# Salman Khan             31
# Sanjay Dutt             26
#                         ..
# Tanishaa Mukerji         1
# Tanuja                   1
# Ankit                    1
# Rakhee Gulzar            1
# Geetika Vidya Ohlyan     1
# Name: count, Length: 566, dtype: int64

# %%
# sort_values 
vk_runs.sort_values() #ascending
# Out:
# match_no
# 8        0
# 87       0
# 93       0
# 91       0
# 206      0
#       ...
# 164    100
# 120    100
# 123    108
# 126    109
# 128    113
# Name: runs, Length: 215, dtype: int64

# %%
# finding the maximum run scored by virat kholi
vk_runs.sort_values(ascending=False).head(1).values[0]   #method chaining
# Out:
# np.int64(113)

# %%
vk_runs = vk_runs.copy()
vk_runs.sort_values(inplace=False) # inplace= True make the change in original data
# Out:
# match_no
# 8        0
# 87       0
# 93       0
# 91       0
# 206      0
#       ...
# 164    100
# 120    100
# 123    108
# 126    109
# 128    113
# Name: runs, Length: 215, dtype: int64

# %%
vk_runs
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
# sort_index
movies.sort_index()
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %%
movies.sort_index(inplace=True) #inplace=True make changes to original data

# %%
movies
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# ## Series Mathematical Methods

# %%
# count - return total items in series except  missing values
vk_runs.count()  # numbers of rows
# Out:
# np.int64(215)

# %%
# sum
subs.sum()
# Out:
# np.int64(49510)

# %%
# product
subs.product()
# Out:
# np.int64(0)

# %%
# mean
subs.mean()
# Out:
# np.float64(135.64383561643837)

# %%
# median
vk_runs.median()
# Out:
# np.float64(24.0)

# %%
# mode
movies.mode()
# Out:
# 0    Akshay Kumar
# Name: lead, dtype: object

# %%
# std
subs.std()
# Out:
# np.float64(62.6750230372527)

# %%
# var
vk_runs.var()
# Out:
# np.float64(688.0024777222343)

# %%
# min/max
vk_runs.max()
# Out:
# np.int64(113)

# %%
vk_runs.min()
# Out:
# np.int64(0)

# %%
# describe
vk_runs.describe()
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %%
subs.describe()
# Out:
# count    365.000000
# mean     135.643836
# std       62.675023
# min       33.000000
# 25%       88.000000
# 50%      123.000000
# 75%      177.000000
# max      396.000000
# Name: Subscribers gained, dtype: float64

# %% [markdown]
# ## Series Indexing and Slicing

# %%
# integer indexing
x = pd.Series([12,13,14,35,46,57,58,79,9])
x[0]
# Out:
# np.int64(12)

# %%
# negative indexing
#x[-1]    #It does not support negative indexing

# %%
movies[0]
# Out:
# C:\Users\sanje\AppData\Local\Temp\ipykernel_16548\3901301928.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   movies[0]
# 'Rajniesh Duggall'

# %%
movies["Uri: The Surgical Strike"]
# Out:
# 'Vicky Kaushal'

# %%
movies[-1]
# Out:
# C:\Users\sanje\AppData\Local\Temp\ipykernel_16548\2731571422.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   movies[-1]
# 'Meghan Jadhav'

# %%
# slicing
vk_runs[5:16]
# Out:
# match_no
# 6      9
# 7     34
# 8      0
# 9     21
# 10     3
# 11    10
# 12    38
# 13     3
# 14    11
# 15    50
# 16     2
# Name: runs, dtype: int64

# %%
# negative slicing
vk_runs[-5:]
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
movies[-5:]
# Out:
# movie
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, dtype: object

# %%
movies[::2]
# Out:
# movie
# 1920 (film)                 Rajniesh Duggall
# 1920: The Evil Returns           Vicky Ahuja
# 2 States (2014 film)            Arjun Kapoor
# 3 A.M. (2014 film)             Salil Acharya
# 3 Idiots                          Aamir Khan
#                                   ...
# Zero (2018 film)              Shah Rukh Khan
# Zila Ghaziabad                  Vivek Oberoi
# Zindaggi Rocks                  Sushmita Sen
# Zindagi Na Milegi Dobara      Hrithik Roshan
# Zokkomon                     Darsheel Safary
# Name: lead, Length: 750, dtype: object

# %%
# Fancy Indexing
vk_runs[[1,3,4,5]]
# Out:
# match_no
# 1     1
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
# indexing with labels
movies['2 States (2014 film)']
# Out:
# 'Arjun Kapoor'

# %% [markdown]
# ## Editing Series

# %%
# using indexing
marks_series
# Out:
# maths       67
# english     57
# science     89
# nepali     100
# Name: marks of sandip, dtype: int64

# %%
marks_series['english']=76
marks_series
# Out:
# maths       67
# english     76
# science     89
# nepali     100
# Name: marks of sandip, dtype: int64

# %%
marks_series[0]=56
marks_series
# Out:
# C:\Users\sanje\AppData\Local\Temp\ipykernel_16548\710656353.py:1: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   marks_series[0]=56
# maths       56
# english     76
# science     89
# nepali     100
# Name: marks of sandip, dtype: int64

# %%
# what if an index does not exist
marks_series['SocialStudies'] = 90  #add new item
marks_series
# Out:
# maths             56
# english           76
# science           89
# nepali           100
# SocialStudies     90
# Name: marks of sandip, dtype: int64

# %%
#slicing
runs_series
# Out:
# 0     13
# 1     24
# 2     56
# 3     78
# 4    100
# dtype: int64

# %%
runs_series[2:4]=[100,100]
runs_series
# Out:
# 0     13
# 1     24
# 2    100
# 3    100
# 4    100
# dtype: int64

# %%
# fancy indexing
runs_series[[0,3,4]]=[0,0,0]
runs_series
# Out:
# 0      0
# 1     24
# 2    100
# 3      0
# 4      0
# dtype: int64

# %%
movies
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %%
movies['2 States (2014 film)']='Alia Bhat'
movies['2 States (2014 film)']
# Out:
# 'Alia Bhat'

# %% [markdown]
# ## Series With Python Functionalities

# %%
# len
print(len(subs))
# Out:
# 365

# %%
# type
print(type(subs))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# dir  -> returns all methods and attributes of "subs" class
print(dir(subs))
# Out:
# ['T', '_AXIS_LEN', '_AXIS_ORDERS', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__bool__', '__class__', '__column_consortium_standard__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__firstlineno__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pandas_priority__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__
# ...

# %%
# sorted -> returns output in a list
print(sorted(subs,reverse=True))
# Out:
# [396, 312, 306, 301, 295, 290, 276, 276, 269, 268, 267, 265, 261, 261, 259, 259, 258, 254, 254, 249, 247, 245, 244, 243, 241, 237, 236, 236, 233, 231, 230, 229, 228, 227, 226, 225, 225, 224, 222, 222, 221, 221, 220, 219, 216, 214, 213, 212, 211, 210, 210, 209, 207, 206, 204, 203, 202, 202, 202, 197, 197, 196, 196, 196, 192, 192, 192, 190, 190, 189, 188, 186, 186, 186, 185, 185, 185, 185, 184, 184, 184, 183, 183, 183, 182, 180, 180, 180, 179, 179, 178, 177, 176, 176, 175, 175, 174, 174, 173, 173, 173, 172, 172, 171, 170, 170, 170, 170, 168, 167, 167, 166, 164, 162, 160, 160, 160, 160, 159, 159, 158, 158, 157, 157, 157, 157, 156, 156, 156, 156, 155, 155, 154, 154, 154, 153, 153, 153, 152, 152, 152, 151, 150, 150, 150, 150, 149, 147, 146, 146, 146, 146, 145, 144, 140, 139, 138, 138, 138, 137, 136, 136, 136, 135, 135, 134, 134, 134, 132, 132, 131, 131, 130, 129, 128, 128, 127, 126, 125, 124, 123, 123, 123, 123, 123, 122, 120, 119, 119, 119, 119, 118, 118, 117, 117, 117, 115, 115, 115, 11
# ...

# %%
# max
print(max(subs))
# Out:
# 396

# %%
# min
print(min(subs))
# Out:
# 33

# %%
# type conversion
list(marks_series)
# Out:
# [56, 76, 89, 100, 90]

# %%
dict(marks_series)
# Out:
# {'maths': np.int64(56),
#  'english': np.int64(76),
#  'science': np.int64(89),
#  'nepali': np.int64(100),
#  'SocialStudies': np.int64(90)}

# %%
# membership operator (in/not in)
'2 States (2014 film)' in movies
# Out:
# True

# %%
movies
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)                 Alia Bhat
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %%
'Ajay Devgn' in movies     #search on index
# Out:
# False

# %%
'Ajay Devgn' in movies.values # search on values
# Out:
# True

# %%
# looping
for i in movies:  # works on values
    print(i)
# Out:
# Rajniesh Duggall
# Sharman Joshi
# Vicky Ahuja
# Manoj Bajpayee
# Alia Bhat
# Barun Sobti
# Salil Acharya
# Naseeruddin Shah
# Aamir Khan
# Aisha Ahmed
# Soha Ali Khan
# Akshaye Khanna
# Neil Nitin Mukesh
# Sara Arjun
# Nargis Fakhri
# Mouli Ganguly
# Vipin Sharma
# Priyanka Chopra
# Juhi Chawla
# Atul Kulkarni
# Kunal Khemu
# Shawar Ali
# Kiran Bhatia
# Shabana Azmi
# Jimmy Sheirgill
# Tiger Shroff
# Sidharth Malhotra
# Prabhu Deva
# Neil Nitin Mukesh
# Govinda
# Naveen Bawa
# Amitabh Bachchan
# Shreyas Talpade
# Sudesh Berry
# Madhuri Dixit
# Paul Sidhu
# Ajay Devgn
# Omkar Das Manikpuri
# Shatrughan Sinha
# Arun Bakshi
# Amitabh Bachchan
# Himesh Reshammiya
# Akshaye Khanna
# Priyanshu Chatterjee
# Amitabh Bachchan
# John Abraham
# Emraan Hashmi
# Aditya Roy Kapoor
# Ishaan Manhaas
# Hrishitaa Bhatt
# Sachiin Joshi
# Nana Patekar
# Amitabh Bachchan
# Farooq Shaikh
# Fardeen Khan
# Prabhas
# Akshay Kumar
# Rahul Dev
# Ranbir Kapoor
# Amitabh Bachchan
# Kareena Kapoor
# ...

# %%
for i in movies.index:
    print(i)
# Out:
# 1920 (film)
# 1920: London
# 1920: The Evil Returns
# 1971 (2007 film)
# 2 States (2014 film)
# 22 Yards
# 3 A.M. (2014 film)
# 3 Deewarein
# 3 Idiots
# 3 Storeys
# 31st October (film)
# 36 China Town
# 3G (film)
# 404 (film)
# 5 Weddings
# 68 Pages
# 7 Hours to Go
# 7 Khoon Maaf
# 7½ Phere
# 88 Antop Hill
# 99 (2009 film)
# 99.9 FM (film)
# ?: A Question Mark
# A Decent Arrangement
# A Flat (film)
# A Flying Jatt
# A Gentleman
# ABCD 2
# Aa Dekhen Zara
# Aa Gaya Hero
# Aabra Ka Daabra
# Aag (2007 film)
# Aagey Se Right
# Aaj Ka Andha Kanoon
# Aaja Nachle
# Aakhari Decision
# Aakrosh (2010 film)
# Aalaap (film)
# Aan: Men at Work
# Aanch
# Aankhen (2002 film)
# Aap Kaa Surroor
# Aap Ki Khatir (2006 film)
# Aapko Pehle Bhi Kahin Dekha Hai
# Aarakshan
# Aashayein
# Aashiq Banaya Aapne
# Aashiqui 2
# Aashiqui.in
# Aasma: The Sky Is the Limit
# Aazaan
# Ab Tak Chhappan 2
# Ab Tumhare Hawale Watan Saathiyo
# Accident on Hill Road
# Acid Factory
# Action Jackson (2014 film)
# ...

# %%
# arithmetic operators(broadcast)
marks_series
# Out:
# maths             56
# english           76
# science           89
# nepali           100
# SocialStudies     90
# Name: marks of sandip, dtype: int64

# %%
100-marks_series
# Out:
# maths            44
# english          24
# science          11
# nepali            0
# SocialStudies    10
# Name: marks of sandip, dtype: int64

# %%
# relational operators
marks_series >60
# Out:
# maths            False
# english           True
# science           True
# nepali            True
# SocialStudies     True
# Name: marks of sandip, dtype: bool

# %%
vk_runs[vk_runs>=50]
# Out:
# match_no
# 15      50
# 34      58
# 41      71
# 44      56
# 45      67
# 52      70
# 57      57
# 68      73
# 71      51
# 73      58
# 74      65
# 80      57
# 81      93
# 82      99
# 85      56
# 97      67
# 99      73
# 103     51
# 104     62
# 110     82
# 116     75
# 117     79
# 119     80
# 120    100
# 122     52
# 123    108
# 126    109
# 127     75
# 128    113
# 129     54
# 131     54
# 132     62
# 134     64
# 137     55
# 141     58
# 144     57
# 145     92
# 148     68
# 152     70
# 160     84
# 162     67
# 164    100
# 175     72
# 178     90
# 182     50
# 188     72
# 197     51
# 198     53
# 209     58
# 213     73
# Name: runs, dtype: int64

# %% [markdown]
# ## Boolean Indexing On Series

# %%
# find number of 50's and 100's scored by kholi
vk_runs[vk_runs >= 50].size
# Out:
# 50

# %%
# find number of ducks of virat kholi
vk_runs[vk_runs == 0].size
# Out:
# 9

# %%
# count number of day when I had more than 200 subs a day
subs[subs > 200].size
# Out:
# 59

# %%
# find actors who have done more than 20 movies
movies.value_counts()[movies.value_counts()>20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %% [markdown]
# ## Plotting Graphs On Series

# %%
subs.plot()
# Out:
# <Axes: >

# %%
movies.value_counts().head(20).plot(kind='bar')
# Out:
# <Axes: xlabel='lead'>

# %%
movies.value_counts().head(20).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Important Series Methods

# %%
# astype
import sys
sys.getsizeof(vk_runs)
# Out:
# 11768

# %%
sys.getsizeof(vk_runs.astype("int16"))
# Out:
# 10478

# %%
# between
vk_runs[vk_runs.between(51,99)].size
# Out:
# 43

# %%
# clip
subs.clip(100,200)
# Out:
# 0      100
# 1      100
# 2      100
# 3      100
# 4      100
#       ...
# 360    200
# 361    200
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# drop_duplicates
temp = pd.Series([1,1,2,2,3,3,4,4])
temp.drop_duplicates()
# Out:
# 0    1
# 2    2
# 4    3
# 6    4
# dtype: int64

# %%
temp.drop_duplicates(keep = 'last')
# Out:
# 1    1
# 3    2
# 5    3
# 7    4
# dtype: int64

# %%
movies.drop_duplicates()
# Out:
# movie
# 1920 (film)               Rajniesh Duggall
# 1920: London                 Sharman Joshi
# 1920: The Evil Returns         Vicky Ahuja
# 1971 (2007 film)            Manoj Bajpayee
# 2 States (2014 film)             Alia Bhat
#                                 ...
# Yeh Saali Aashiqui            Vardhan Puri
# Zed Plus                     Vinod Acharya
# Zid (2014 film)             Mannara Chopra
# Zindagi 50-50                  Veena Malik
# Zor Lagaa Ke...Haiya!        Meghan Jadhav
# Name: lead, Length: 567, dtype: object

# %%
# duplicated
temp.duplicated().sum()
# Out:
# np.int64(4)

# %%
vk_runs.duplicated().sum()
# Out:
# np.int64(137)

# %%
# isnull
temp = pd.Series([1,2,3,np.nan,5,6,np.nan,8,np.nan,10])
temp.isnull().sum()
# Out:
# np.int64(3)

# %%
temp.size   # consider the missing values
# Out:
# 10

# %%
temp.count()  # doesnot consider the null values
# Out:
# np.int64(7)

# %%
vk_runs.isnull().sum()
# Out:
# np.int64(0)

# %%
# dropna
temp.dropna()
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 4     5.0
# 5     6.0
# 7     8.0
# 9    10.0
# dtype: float64

# %%
# fillna
temp.fillna(temp.mean())
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     5.0
# 4     5.0
# 5     6.0
# 6     5.0
# 7     8.0
# 8     5.0
# 9    10.0
# dtype: float64

# %%
# isin
vk_runs[(vk_runs == 49) | (vk_runs == 99)]
# Out:
# match_no
# 82    99
# 86    49
# Name: runs, dtype: int64

# %%
vk_runs[vk_runs.isin([49,99])]
# Out:
# match_no
# 82    99
# 86    49
# Name: runs, dtype: int64

# %%
# apply -> helps to apply custom logic
movies.apply(lambda x: x.split()[0].upper())
# Out:
# movie
# 1920 (film)                 RAJNIESH
# 1920: London                 SHARMAN
# 1920: The Evil Returns         VICKY
# 1971 (2007 film)               MANOJ
# 2 States (2014 film)            ALIA
#                               ...
# Zindagi 50-50                  VEENA
# Zindagi Na Milegi Dobara     HRITHIK
# Zindagi Tere Naam             MITHUN
# Zokkomon                    DARSHEEL
# Zor Lagaa Ke...Haiya!         MEGHAN
# Name: lead, Length: 1500, dtype: object

# %%
subs.apply(lambda x : "Good Day" if x > subs.mean() else "Bad Day")
# Out:
# 0       Bad Day
# 1       Bad Day
# 2       Bad Day
# 3       Bad Day
# 4       Bad Day
#          ...
# 360    Good Day
# 361    Good Day
# 362    Good Day
# 363    Good Day
# 364    Good Day
# Name: Subscribers gained, Length: 365, dtype: object

# %%
# copy
vk_runs
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
new = vk_runs.head()  # This does not give copy of data, head() and tail() gives view of data.
                      # Changes to them also change the original data.
new
# Out:
# match_no
# 1    100
# 2     23
# 3     13
# 4     12
# 5      1
# Name: runs, dtype: int64

# %%
new[1] = 100

# %%
new = vk_runs.head().copy()  # use copy() instead of view
new
# Out:
# match_no
# 1    100
# 2     23
# 3     13
# 4     12
# 5      1
# Name: runs, dtype: int64

# %%
new[1] = 10

# %%
new
# Out:
# match_no
# 1    10
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
vk_runs
# Out:
# match_no
# 1      100
# 2       23
# 3       13
# 4       12
# 5        1
#       ...
# 211      0
# 212     20
# 213     73
# 214     25
# 215      7
# Name: runs, Length: 215, dtype: int64
